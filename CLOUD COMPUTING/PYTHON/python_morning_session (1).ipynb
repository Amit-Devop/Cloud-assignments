# %% [markdown]
# **PYTHON Programming Language**

# %%
# Python  is a high level language (that is closer human like language )
# Readibility : python syntax is clear and concise
#versatility : it support multiple programming paradigms
# community support : python has a large and active community  which contributes to a wealth of libraries
# and various framework

# Python was created by Guido Van Rossum in 1991 .
# Python is used in various fields like web development , artifical intelligence , machine learning

# %%
# java
public class Helloworld{
    public static void main(String[]args){
        System.out.println("Hello world")
    }
}

# %%
print("HELLO WORLD")  # THIS IS PRINT FUNCTION AND IT IS PRINTING HELLO WORLD
# Out:
# HELLO WORLD

# %%
# COMMENTS :
"""this is sum
which is adding two number
and print is printing the sum to me"""


SUM = 2+5

print(SUM)
# Out:
# 7

# %% [markdown]
# **# variables**

# %%
myvar = 'kibiuyf'
print(myvar)
# Out:
# kibiuyf

# %%
 = 787
print(12132myvar)
# Out:
#   File "<ipython-input-7-213e5f80f678>", line 1
#     12132myvar = 787
#         ^
# SyntaxError: invalid decimal literal

# %%
myvar1223 =88

# %% [markdown]
# RULES TO CREATE VARABLES

# %%
# a variables cannot start with a number

# A variable can contain alpha-numeric characters

# A variable cannot use any special character except underscore


# Variable names are case- sensitive

# %%
age = 12
age = 10
age = 16
print(age)
# Out:
# 16

# %%
myvar = 12
print(myvar)
# Out:
# 12

# %%
my_var =90
print(my_var)
# Out:
# 90

# %%
_MY_var ='kishan'
print(_MY_var)
# Out:
# kishan

# %%
23_myvar = 89
print(23_myvar)
# Out:
#   File "<ipython-input-17-2f8ca9dfe155>", line 1
#     23_myvar = 89
#       ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# #3. **DATATYPE**

# %%
myvar = 45
print(type(myvar))
# Out:
# <class 'int'>

# %%
#  : those are whole number such as 1,2 34, ------ etc they dont have fractional or decimal and
# unlimited length

x =12984334837847985846587465843685438584375843
print(type(x))
# Out:
# <class 'int'>

# %%
# Float :  those numbers with decimal parts like : 34.8 , 67.7
x = -34.7
print(type(x))
# Out:
# <class 'float'>

# %%
my ="ygfegfyefgqwgfyugyugfyufye"
var = '12345mywgfeyegfgegyfgf'

my ="768678565744747"
print(type(my))
# Out:
# <class 'str'>

# %% [markdown]
# # 1. Indexing

# %%
a='hello world'


# positive indexing starts from left to right ( first character should be stored in index number 0)
# negative indexing starts from right to left (last character should be stored in index number -1 to --)

print(a[0])


print(a[1])
print(a[-1])
# Out:
# h
# e
# d

# %%
animal = "Lion"
print(animal[0])
print(animal[-1])
print(animal[2])
print(animal[3])
# Out:
# L
# n
# o
# n

# %% [markdown]
# # slicing

# %%
# it will give you range of charcters
a='helloworld'

print(a[0:5])     #print([startindex : endindex+1])
# Out:
# hello

# %%
a='hello world'
print(a[0: ])
# Out:
# hello world

# %% [markdown]
# nexting slicing

# %%
a ='hello world'
print(a[-5 : ])
print(a[-2: ])

print(a[ : ])
# Out:
# world
# ld
# hello world

# %%
# modify

a ='hello world'
print(a.upper())    # 1 uppers() : convert into upper case

a ='HELLO WORLD'
print(a.lower())     # 2. lower() : convert into lower case

a ='yello everyone'             # 3.  replace : replace a string or character  with another character

print(a.replace("y","H"))


Fruits = "apple ,banana,orange"
print(Fruits.split(","))
# Out:
# HELLO WORLD
# hello world
# Hello everHone
# ['appl', ' ,banana,orang', '']

# %%
a = "hello,world"
b = "ROOM"
print (a.upper())
print (b.lower())
print(a.replace("h" , "H"))
print(a.split("/"))
# Out:
# HELLO,WORLD
# room
# Hello,world
# ['hello,world']

# %%
a = "Hello,World"
print(a.split(","))
# Out:
# ['Hello', 'World']

# %% [markdown]
# Boolean datatypes

# %%
a =10
b = 9      # either True OR false
print(a<b)
# Out:
# False

# %%
print(10==9)
# Out:
# False

# %%
print("hello"=="hello")
# Out:
# True

# %% [markdown]
# # Sequential Datatypes:
#  #1 . List
#  # 2. Tuple
#  #3 . Dictionary
#  #4. Sets

# %%
# LIST : IT  is used to store a sequence of time with any kind of type of data

# 1 . []
#2 . list is ordered  :> it means items have a defined ordered or index

# 3> list is changeable(mutuable) : we can do any modification inside the list

# 4 > it allow duplicates value

# %%
list1 = [1,2,3,4,10,20,20]
print(list1)
print(len(list1))
# Out:
# [1, 2, 3, 4, 10, 20, 20]
# 7

# %%
list2 =['abc',24,34.6,True,'male']
print(list2)
# Out:
# ['abc', 24, 34.6, True, 'male', '$']

# %%
color =['red','green','blue','black']

print(color[1])
print(color[-1])
print(color[ : ])
# Out:
# green
# black
# ['red', 'green', 'blue', 'black']

# %%
print(color[0:3])
print(color[ :4])
# Out:
# ['red', 'green', 'blue']
# ['red', 'green', 'blue', 'black']

# %%
# change the items inside the list

list1 =['coffee','sugar','milk']

list1[1] = 'tea'
print(list1)
# Out:
# ['coffee', 'tea', 'milk']

# %%
list2 = ['carrot','onion','capsicum','potato']
list2[0:2]  =['blue','orange']
print(list2)
# Out:
# ['blue', 'orange', 'capsicum', 'potato']

# %%
# insert function :

list2 = ['carrot','onion','capsicum','potato']

list2.insert(2,'tomato')
print(list2)
# Out:
# ['carrot', 'onion', 'tomato', 'capsicum', 'potato']

# %%
list2 =['boy', 'shut','chup']
list2[0:2] =['blue','orange']
print(list2) #and got result ['blue', 'orange', 'shut', 'chup']
# Out:
# ['blue', 'orange', 'chup']

# %%
# append :

list1 =['apple','orange','grapes']

list1.append('cat')
print(list1)
# Out:
# ['apple', 'orange', 'grapes', 'cat']

# %%
# EXTEND

LIST1 =['red','orange','green']
list2 =['blue','grey','black']
LIST1.extend(list2)
print(LIST1)
# Out:
# ['red', 'orange', 'green', 'blue', 'grey', 'black']

# %%
# REMOVE:


LIST1 =['red','orange','green']

LIST1.remove('red')
print(LIST1)
# Out:
# ['orange', 'green']

# %%
#  the pop function remove the specfied index value
list1 = ['family','uncle','aunt','mom','dad']
list1.pop(3)
print(list1)
# Out:
# ['family', 'uncle', 'aunt', 'dad']

# %%
list1 = ['family','uncle','aunt','mom','dad']

del list1
print(list1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-0715a085dcf2> in <cell line: 4>()
#       2
#       3 del list1
# ----> 4 print(list1)
#
# NameError: name 'list1' is not defined

# %%
list1 = ['family','uncle','aunt','mom','dad']

list1.clear()
print(list1)
# Out:
# []

# %%
list1 =['mango','abc','how are you']
list1.sort()
print(list1)
# Out:
# ['abc', 'how are you', 'mango']

# %%
list2 =[120,40,60,4,7]   # descending order
list2.sort(reverse =True)
print(list2)
# Out:
# [120, 60, 40, 7, 4]

# %%
list1 =[56,'lion','kiwi',38]
#list1.sort()
#print(list1)
new_list=list1.copy()                       # copy method
print(new_list)
# Out:
# [56, 'lion', 'kiwi', 38]

# %% [markdown]
# # Tuple

# %%
# 1  it is used to store multiple items in a single variable

# 2 .  A tuple is a ordered
 # 3 . it is unchanagable (immutable)

#4 ()

# %%
tuple1 =('apple','pineapple','orange')
print(tuple1)
# Out:
# ('apple', 'pineapple', 'orange')

# %%
print(len(tuple1))
# Out:
# 3

# %%
# access element


mytuple1 =('woho','keo','roe','jiu')
print(mytuple1[0])
print(mytuple1[-1])
print(mytuple1[0:3])
# Out:
# woho
# jiu
# ('woho', 'keo', 'roe')

# %%
x =('hi','hello','why','my')  # created a tuple
y=list(x)
print(y)
y[0] ='bye'
print(y)

x=tuple(y)
print(x)
# Out:
# ['hi', 'hello', 'why', 'my']
# ['bye', 'hello', 'why', 'my']
# ('bye', 'hello', 'why', 'my')

# %%
tuple3=('apple','pine','banana','orange')
y=list(tuple3)
print(y)
y[2]='Pineapple'
print(y)

x=tuple(y)
print(x)
# Out:
# ['apple', 'pine', 'banana', 'orange']
# ['apple', 'pine', 'Pineapple', 'orange']
# ('apple', 'pine', 'Pineapple', 'orange')

# %%
thistuple = ("a","b","c")
x=list(thistuple)
print(x)

x.pop(1)
print(x)


thistuple=tuple(x)
print(thistuple)
# Out:
# ['a', 'b', 'c']
# ['a', 'c']
# ('a', 'c')

# %%
tuple2 =('apple','banana','cherry','papaya')
list1=list(tuple2)
print(list1)


list1[0:3] =('kiwi','pineapple','guava')

print(list1)




tuple2=tuple(list1)

print(tuple2)
# Out:
# ['apple', 'banana', 'cherry', 'papaya']
# ['kiwi', 'pineapple', 'guava', 'papaya']
# ('kiwi', 'pineapple', 'guava', 'papaya')

# %%
# del

tuple2 =('apple','banana','cherry','papaya')


del tuple2
print(tuple2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-c84bb1392b06> in <cell line: 7>()
#       5
#       6 del tuple2
# ----> 7 print(tuple2)
#
# NameError: name 'tuple2' is not defined

# %%
# join two tuples
tuple1 =("a","b","c")
tuple2 =(1,2,3)


print(tuple1+tuple2)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
"""tuple1 =("a","b","c")

new_tuple = tuple1.copy()
print(new_tuple)"""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-6692971ae3bb> in <cell line: 3>()
#       1 tuple1 =("a","b","c")
#       2
# ----> 3 new_tuple = tuple1.copy()
#       4 print(new_tuple)
#
# AttributeError: 'tuple' object has no attribute 'copy'

# %% [markdown]
# # Sets

# %%
# 1. it is used  to store multiple items in a single variables

# 2 > A SET IS A unordered or undindexed :   we cannot be sure in which order the items will appear

# 3 >  A set is unchangable

# 4.  it does not allow duplicates values

# %%
set1 ={'apple','banana','orange','peine'}
print(set1)
# Out:
# {'peine', 'orange', 'banana', 'apple'}

# %%
a = {'banana' ,'apple', 'orange'}
print(a)
# Out:
# {'orange', 'banana', 'apple'}

# %%
set2 = {'apple','banana','orange',34, True,0}
print(set2)
# Out:
# {0, True, 34, 'orange', 'banana', 'apple'}

# %%
set3 = {'apple','banana','orange',34, True,0,False,1}
print(len(set3))
# Out:
# 6

# %%
set = {1,3,4,6,7,8,0}

print(set)
# Out:
# {0, 1, 3, 4, 6, 7, 8}

# %%
set1 = {1,3,4,6,7,8,0}
print(len(set1))
# Out:
# 7

# %%
"""set1 = {1,3,4,6,7,8}
x=list(set1)
print(x)

print(x[0])

set1 = set(x)
print(set1)"""

a = {'banana' ,'apple', 'orange', True, 0, False, 5}
b = list(a)
print(b)
b.append("Mario")
print(b)
a = set(b)
print(a)
# Out:
# [0, True, 5, 'apple', 'orange', 'banana']
# [0, True, 5, 'apple', 'orange', 'banana', 'Mario']
# {0, True, 5, 'Mario', 'banana', 'orange', 'apple'}

# %%
thisset ={'yellow','blue','orange'}

thisset.add('red')
print(thisset)
# Out:
# {'orange', 'yellow', 'red', 'blue'}

# %%
set1= {'bottle','water','milk'}
set2 ={'ring','card','play'}


set1.update(set2)
print(set1)
# Out:
# {'play', 'bottle', 'ring', 'water', 'milk', 'card'}

# %%
# remove set item


thisets ={'hiu','iu','yu'}
thisets.remove('yu')
print(thisets)
# Out:
# {'hiu', 'iu'}

# %%
thisets ={'hiu','iu','yu'}
thisets.discard('hiu')
print(thisets)#
# Out:
# {'iu', 'yu'}

# %%
thisets ={'hiu','iu','yu'}
thisets.pop()
print(thisets)
# Out:
# {'iu', 'yu'}

# %%
set1 ={'icic bank',364726476476473,989787767,67000,67000}
print(set1)
# Out:
# {67000, 364726476476473, 'icic bank', 989787767}

# %%
# clear


set1 ={'icic bank',364726476476473,989787767,67000,67000}
set1.clear()
print(set1)
# Out:
# set()

# %% [markdown]
# #Dictionary

# %%
# A dictionary is used to store data in  key: value


dict1 = {
    'brand':'ford',
    'color':'blue',
    'year':2020
}
print(dict1)
# Out:
# {'brand': 'ford', 'color': 'blue', 'year': 2020}

# %%
print(len(dict1))
# Out:
# 3

# %%
dict1 = {
    'brand':'ford',
    'color':'blue',
    'year':2020
}
#print(dict1)

print(dict1['brand'])
# Out:
# ford

# %%
students ={
    'Name':'Rohit',
    'MARKS':90,
    'Percentage':'84%'
}

print(students['MARKS'])
# Out:
# 90

# %%
students ={
    'Name':'Rohit',
    'MARKS':90,
    'Percentage':'84%'
}

print(students.get('Percentage'))
# Out:
# 84%

# %%
students ={
    'Name':'Rohit',
    'MARKS':90,
    'Percentage':'84%'
}
print(students.keys())
# Out:
# dict_keys(['Name', 'MARKS', 'Percentage'])

# %%
students ={
    'Name':'Rohit',
    'MARKS':90,
    'Percentage':'84%'
}


print(students.values())
# Out:
# dict_values(['Rohit', 90, '84%'])

# %%
students ={
    'Name':'Rohit',
    'MARKS':90,
    'Percentage':'84%'
}
print(students.items())
# Out:
# dict_items([('Name', 'Rohit'), ('MARKS', 90), ('Percentage', '84%')])

# %%
students ={
    'Name':'Rohit',
    'MARKS':90,
    'Percentage':'84%'
}

students['Percentage'] ='74%'
print(students)
# Out:
# {'Name': 'Rohit', 'MARKS': 90, 'Percentage': '74%'}

# %%
students ={
    'Name':'Rohit',
    'MARKS':90,
    'Percentage':'84%'
}


students.update({'Percentage':'74%'})
print(students)
# Out:
# {'Name': 'Rohit', 'MARKS': 90, 'Percentage': '74%'}

# %%
students ={
    'Name':'Rohit',
    'MARKS':90,
    'Percentage':'84%'
}

students['grade'] ='A'
print(students)
# Out:
# {'Name': 'Rohit', 'MARKS': 90, 'Percentage': '84%', 'grade': 'A'}

# %%
students ={
    'Name':'Rohit',
    'MARKS':90,
    'Percentage':'84%'
}

students.update({'grade':'A'})
print(students)
# Out:
# {'Name': 'Rohit', 'MARKS': 90, 'Percentage': '84%', 'grade': 'A'}

# %%
students ={
    'Name':'Rohit',
    'MARKS':90,
    'Percentage':'84%'
}
students.pop('Name')
print(students)
# Out:
# {'MARKS': 90, 'Percentage': '84%'}

# %%
students ={
    'Name':'Rohit',
    'MARKS':90,

}

students.popitem()
print(students)
# Out:
# {'Name': 'Rohit'}

# %%
# List of student names
students = ["Alice", "Bob", "Charlie", "Daisy"]

# Print a greeting message for each student
for student in students:
    print("Hello,",student,"! Welcome to the class.")
# Out:
# Hello, Alice ! Welcome to the class.
# Hello, Bob ! Welcome to the class.
# Hello, Charlie ! Welcome to the class.
# Hello, Daisy ! Welcome to the class.

# %%
a = {
    'brand': 'Ford',
    'Colour': 'White',
    'year': 2020
}
a.clear()
print(a)
# Out:
# {}

# %% [markdown]
# **Operators**

# %%
# operators  are used to perform the operations on variables and values


#10+6

# %% [markdown]
# 1 . Arthemetic opertor

# %%
# Addition


x = 3
y = 4
print("addition of x+y is :",x+y)
# Out:
# addition of x+y is : 7

# %%
num1 = 78
num2 =90

print("subtraction of num1 and num2 is", num1-num2)
# Out:
# subtraction of num1 and num2 is -12

# %%
num1 = 67
num2 = 6
print("Multiplication of num1 and num2 is", num1 * num2)
# Out:
# Multiplication of num1 and num2 is 402

# %%
# Division opertions

x = 12
y = 3
print(x/y) # quotient
# Out:
# 4.0

# %%
# modulus opertor

num1 = 10
num2 = 5
print(num1 % num2)
# Out:
# 0

# %%
#floor division


num1 = 10
num2 =3
print(num1 // num2)
# Out:
# 3

# %% [markdown]
# # Assignment operator

# %%
# it is used to assign a values to a variables

# %%
x = 'hfi2hf'
print(x)
# Out:
# hfi2hf

# %%
 # addition assignment opertor

x =5
x+=4

print(x)  # x=5+4
# Out:
# 9

# %%
# substraction assignment opertor

x = 6
x -=4
print(x)
# Out:
# 2

# %%
# multipication assignment operator

x =6
x*=4
print(x)
# Out:
# 24

# %% [markdown]
# comparison opertor

# %%
# It is used to compare values


x =10
y =20
print(x==y)
# Out:
# False

# %%
# not equal (!)
x =5
y =5
print(x != y)
# Out:
# False

# %%
x=3
y=5
print(x != y )
# Out:
# True

# %%
# greater than

x =10
y =20
print(x>y)
# Out:
# False

# %%
# less than (<)

x = 10
y = 20
print(x<y)
# Out:
# True

# %%
# greater than equal to  >=
x =20
y = 10
print(x>=y)
# Out:
# True

# %%
# less than equal to <=
x = 5
y = 10
print(x <=y)
# Out:
# True

# %%
print(x<=y)
# Out:
# True

# %% [markdown]
# #logical operator **

# %%
# it is used to combine some conditional statements
# AND / OR / NOT

# %%
# AND  :  BOTH THE EVENT SHOULD BE HAPPEN ~ TRUE
# OR  :  ANY ONE OF THE CONDITION SHOULD BE TRUE  ~ TRUE
# NOT  :  reverse the output

# %%
x = 15
print(x>15 and x <20)
# Out:
# False

# %%
# or
x =5
print(x>3 or x<4)
# Out:
# True

# %%
# not
x =4
print(not(x>3 and x<2))
# Out:
# True

# %%
x =10
print(not(x>6 or x<5))
# Out:
# False

# %%
x = 5
print(not(x<10 and x==5))
# Out:
# False

# %%
x = 5
print(not(x<10 and x==5))
# Out:
# False

# %% [markdown]
# **# Membership operator**

# %%
# it is used to find if a particular item is present inside sequence or not

# in / not in

x =['apple','orange']
print('orange' in x)
# Out:
# True

# %%
x =['coffee','suagr','milk','bread']
print('cell' not in  x)
# Out:
# True

# %%
x = ['coffee','sugar','milk','bread']
print('cell' not in x and 'coffee' not in x )
# Out:
# False

# %% [markdown]
# **conditional statements**

# %%
# based upon some conditions the expression can be evluated

# %%
# If statement
age = 10
if age>=18:

  print(" you are an adult")

# %%
age = 15
if age>=18:

  print("You are an adult")

# %%
a =  200
b = 500

if b>a:
  print("b is greater")
# Out:
# b is greater

# %%
# else statement
age =12
if age >= 18:
  print("you are an adult")

else:
  print("you are not  an adult")
# Out:
# you are not  an adult

# %%
a =  200
b = 100

if b>a:
  print("b is greater")

else:
  print("a is greater")
# Out:
# a is greater

# %%
age = int(input("enter your age :"))

print(type(age))

if age>=18:
  print("you are an adult")

else:
  print("you are teenager")
# Out:
# enter your age :45
# <class 'int'>
# you are an adult

# %%
marks = float(input("enter your marks"))

if marks>=70:
  print("good job")
else:
  print("average")
# Out:
# enter your marks89
# good job

# %%
# elif : To check multiple conditions


a = int(input("enter a first number:"))
b = int(input("enter a second number"))

if b>a:
  print("b is greater")

elif a==b:
  print("a is equal to b")


elif a>b:
  print("a is greater")

else:
  print("none")
# Out:
# enter a first number:34
# enter a second number22
# a is greater

# %%
marks = float(input("enter your marks:"))
if marks>=80:
    print("you are excellent")

elif marks==90:
    print("you are outstanding")

elif marks<=80:
    print("you are average")
# Out:
# enter your marks:90
# you are excellent

# %%
grade = input("enter your grades :")

if  grade =='A':
  print("outstanding")

elif grade =='B':
  print("excellent")

elif grade == 'C':
  print("Average")


else :
  print("better luck next time ")
# Out:
# enter your grades :c
# better luck next time

# %%
# ask the user to enter his age
#  first condition :  age <0 then ask the user invalid age

# second condition :  age is less than 18    ask the user you are a kid

# third condition  : age is greater 65 : ask the user you are senior citizen

# %%
a= int(input("Enter your age:"))
if a < 0:
    print("Invalid age")
elif a < 18:
    print("you are a kid")
elif a > 65:
    print("you are senior citizen")
else:
    print("you are an adult")
# Out:
# Enter your age:70
# you are senior citizen

# %%
a = int(input("Enter your Age:"))


if a < 0:
    print("age is invalid")

elif a < 18:
    print("You are a Kid")

elif a > 65:
    print("You are Senior Citizen")

else:
    print("You are fit and fine")
# Out:
# Enter your Age:54
# You are fit and fine

# %%
Age = int(input("Enter your age"))
if(Age < 0):
  print("Invalid age")
elif(Age < 18):
  print("You are a kid")
elif(Age > 60):
  print("You are a senior citizen")
else:
  print("You are adult")
# Out:
# Enter your age57
# You are adult

# %% [markdown]
# **#Looping statements**

# %%
#it executes a set of conditions as long as the condition is statisfied or true


# while / for loop

# %%
i=1
while i<6:
  print(i)
  i+=1   # i = 3+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# user enter any string  loop will be excuted until the user will not exit if the user entered exit then
# the condition become true the loop will terminated


user_input = ''
while user_input !='exit':
  user_input  = input("enter a string and to stop the loop type exit :")

  print("user typed",user_input)
# Out:
# enter a string and to stop the loop type exit :musk
# user typed musk
# enter a string and to stop the loop type exit :uifw
# user typed uifw
# enter a string and to stop the loop type exit :dwiq
# user typed dwiq
# enter a string and to stop the loop type exit :ihefh
# user typed ihefh
# enter a string and to stop the loop type exit :exit
# user typed exit

# %%
user_input = str(1)

print(type(user_input))

while user_input != "Exit":
    user_input = input(" Enter your String Again :")

print(" User Entered ",user_input)
# Out:
# <class 'str'>
#  Enter your String Again :mufue
#  Enter your String Again :kue
#  Enter your String Again :Exit
#  User Entered  Exit

# %%
a ='hello world'

# %%
user_input= 1
while user_input !='exit' :
     user_input = input("enter the string and to stop enter exit  ")
print("user typed:", user_input)
# Out:
# enter the string and to stop enter exit  ornw
# enter the string and to stop enter exit  nieyrn
# enter the string and to stop enter exit  nifenf
# enter the string and to stop enter exit  exit
# user typed: exit

# %%
#  intialize a i variable as 1
# use while loop that start from  i and end till less than equal to 6
# print hello how are you
# then  increment the i

# %%
a = 0
while a < 6:
    print ("How are you ")
    a += 1
# Out:
# How are you
# How are you
# How are you
# How are you
# How are you
# How are you

# %%
i = 1

while i <= 6:
    print("hello how are you?")
    i +=1
# Out:
# hello how are you?
# hello how are you?
# hello how are you?
# hello how are you?
# hello how are you?
# hello how are you?

# %%
# break statement it will  break the iteration and exit from the loop

i =1
while i<10:
   if i == 5:
     break
   print(i)

   i+=1
# Out:
# 1
# 2
# 3
# 4

# %%
"""number = [1,3,5,7,9]
for num in number:
  if  num >5:
    print("greater number ",num)
    break"""
# Out:
# greater number  7

# %%
numbers = [1, 3, 5, 7, 9]
i = 0
print(len(numbers))

while i < len(numbers):
    if numbers[i] > 5:
        print("greater number is",number[i])
        break
    i += 1
# Out:
# 5
# greater number is 7
